# %%
### 객체지향 프로그래밍(Object Oriented Programming)

## 함수기반의 프로그래밍을 하면 좋다는 걸 알게 되었다
## 꽤 예전(1970년대)부터 시작해서 지금까지 절차적프로그래밍을 하고있다
## 장점 : 프로그래밍이 쉽다! => 빨리 만들 수 있다
##        => 비용이 적게 든다
## 단점 : 처음에는 단점이 별로 없어보였다
##        1990년 들어오며 세상이 변하기 시작했다 => 인터넷보급
##        정보량이 폭발적으로 증가하며 => 세상이 급변하기 시작
##        프로그램의 유지보수 요구가 급증
##        절차적 프로그램으로 프로그램을 작성해서 이런 문제가 발생
##        변화에 취약하기 때문
##        어떤 방식으로 프로그램을 만들면 유지보수측면에서 이점이 있을까?

## 90년대 기준으로 프로그래밍 방식이 
## 객체지향으로 전면적으로 전환됨
## 객체지향이 어떤 프로그래밍 방식인지 인지
## 현실세계에 부합(변화에 잘 적응하는)하는 프로그램을 만들기 위해 
## 해결해야 하는 현실세계 문제를 
## 프로그램으로 똑같이 모델링하면 되지 않을까? 

## 은행프로그램을 만든다고 가정하자
## 은행프로그램을 구성하는 요소를 파악
## 텔러, 고객, 은행계좌, 지점, 테이블....
## 분석하는 사람마다 구성요소가 다르다
## 구성요소간의 상호작용 행위를 정의하는 프로그래밍 => 객체지향

## 예로 은행계좌(객체)를 프로그램으로 표현(객체모델링)
## 객체들은 크게 2가지로 파악할 수 있다
## 상태와 행위로 파악 = 추상화(abstraction)
## 상태는 값으로 표현되는 것. 행위는 동작으로 표현되는 것
## 상태 값: 잔액, 예금주, 계좌번호,...
## 행위 : 출금, 입금, 조회
##
## class => 객체 모델링의 수단, 추상 데이터 타입(새로운 데이터 타입을 만들 수 있음)


## 파이선의 객체 모델링 방법

## 클래스 이름은 대문자로 시작(관용적) 
#     <> 함수명은 소문자

class Student:
    # properties(속성)
    # = 상태(값) : 이름, 학과, 학년, 학번, 성별, 성적, (나이, 키, 몸무게...)
    # 변수로 표현
    # Java:filed, C++:memberfeild, Python:properties(속성)
    s_nation = "" # classvariable (모든객체가 공유하는 변수)
    # 생성자(constructor)
    # class에 묘사된 내용을 기본으로 메모리 공간을 잡아서 객체를 표시해주는데
    # 그 공간을 어떻게 잡을지를 정해주어야 한다.
    # 정한 방식에 따라 생성자가 객체를 만들어 줌
    def __init__(self,n):   # 정해져있음
        self.s_name = n     # instance variable (객체가 독립적으로 가지고 있는 변수)
        Student.s_num = ""     # instance variable (객체가 독립적으로 가지고 있는 변수)
        self.s_major = []   # 전공 2개를 list로 밀어넣을 수 있다
        
    # method
    # (행위)
    # 함수로 표현
    def display(self):
        print("학생이름은: {}".format(self.s_name))

        
t = Student("홍길동") # 객체 생성 . 홍길동이 생성자의 self.n의 n
                      # n으로 가서 s_name의 n에 저장되 
print(t.s_name)
t.display()

Student.s_nation ="한국"
print(t.s_nation)

k = Student("김연아") # 객체
print(k.s_name)
k.display()
print(k.s_nation)


students = list()
students.append(Student("홍길동")) # 객체
print(students[0].s_name)


# Class 는 새롭게 저장할 수 있는 자료구조를 만드는 것이라고 정리할 수 있다 


###############

# 공간을 호출 => 이 코드에 의해 만들어진 
# 메모리 저장공간(instance) => 객체 
# 클래스 내부에 정의된 생성자라고 불리는
# 함수가 호출됨됨
# Out:
# 홍길동
# 학생이름은: 홍길동
# 한국
# 김연아
# 학생이름은: 김연아
# 한국
# 홍길동

# %%
class Student:
    # properties(속성)
    # = 상태(값) : 이름, 학과, 학년, 학번, 성별, 성적, (나이, 키, 몸무게...)
    # 변수로 표현
    # Java:filed, C++:memberfeild, Python:properties(속성)
    s_nation = "" # classvariable (모든객체가 공유하는 변수)
    s_num = ""
    s_graduate = ""
    # 생성자(constructor)
    # class에 묘사된 내용을 기본으로 메모리 공간을 잡아서 객체를 표시해주는데
    # 그 공간을 어떻게 잡을지를 정해주어야 한다.
    # 정한 방식에 따라 생성자가 객체를 만들어 줌
    def __init__(self,n,a):   # 정해져있음
        self.s_name = n# instance variable (객체가 독립적으로 가지고 있는 변수)
        self.s_num = a     # instance variable (객체가 독립적으로 가지고 있는 변수)
        self.s_major = []   # 전공 2개를 list로 밀어넣을 수 있다
        self.s_momo = ""
    # method
    # (행위)
    # 함수로 표현
    def display(self):
        print("학생이름은: {}".format(self.s_name))
        

lag = Student("홍길동", 20142415) 
print(lag.s_name, lag.s_num)
lag.s_major.append("컴공")
print(lag.s_major)
# Out:
# 홍길동 20142415
# ['컴공']
